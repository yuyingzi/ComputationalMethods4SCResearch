# %% [markdown]
# # Sarcasm-enhanced sentiment classification
#
# The maintained experiment lives in `EnhancedwithSarcasm_pretrain.py`. Run this notebook from the `EnhancedSentimentwithSarcasm` directory.

# %%
# %run ./EnhancedwithSarcasm_pretrain.py
